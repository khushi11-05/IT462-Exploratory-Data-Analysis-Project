# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('varitey_commodity_total.csv')
df
# Out:
#           State   District     Market           Commodity      Variety Grade  \
# 0       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 1       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 2       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 3       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 4       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# ...         ...        ...        ...                 ...          ...   ...
# 320318  Gujarat  Ahmedabad   Viramgam         Castor Seed  Castor seed   FAQ
# 320319  Gujarat  Ahmedabad   Viramgam         Castor Seed  Castor seed   FAQ
# 320320  Gujarat  Ahmedabad   Viramgam  Cummin Seed(Jeera)        Other   FAQ
# 320321  Gujarat  Ahmedabad   Viramgam  Cummin Seed(Jeera)        Other   FAQ
# 320322  Gujarat  Ahmedabad   Viramgam  Cummin Seed(Jeera)        Other   FAQ
#
#        Arrival_Date  Min_Price  Max_Price  Modal_Price  Commodity_Code
# 0        03/01/2006      600.0     1300.0       1100.0              81
# 1        05/01/2006     1100.0     1400.0       1300.0              81
# 2        16/01/2006     1500.0     1800.0       1800.0              81
# 3        19/01/2006      700.0      900.0        800.0              81
# 4        24/01/2006      500.0     1400.0       1000.0              81
# ...             ...        ...        ...          ...             ...
# 320318   18/10/2024     6525.0     6620.0       6570.0             123
# 320319   19/10/2024     6425.0     6580.0       6500.0             123
# 320320   07/11/2024    21450.0    22200.0      21825.0              42
# 320321   19/10/2024    21850.0    22850.0      22350.0              42
# 320322   23/10/2024    20850.0    23200.0      22025.0              42
#
# [320323 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# State             0
# District          0
# Market            0
# Commodity         0
# Variety           0
# Grade             0
# Arrival_Date      0
# Min_Price         0
# Max_Price         0
# Modal_Price       0
# Commodity_Code    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(35)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Arrival_Date'] = pd.to_datetime(df['Arrival_Date'], format='%d/%m/%Y')

df['Arrival_Day'] = df['Arrival_Date'].dt.day
df['Arrival_Month'] = df['Arrival_Date'].dt.month
df['Arrival_Year'] = df['Arrival_Date'].dt.year

df
# Out:
#           State   District     Market           Commodity      Variety Grade  \
# 0       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 1       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 2       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 3       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# 4       Gujarat  Ahmedabad  Ahmedabad        Bitter gourd        Other   FAQ
# ...         ...        ...        ...                 ...          ...   ...
# 320318  Gujarat  Ahmedabad   Viramgam         Castor Seed  Castor seed   FAQ
# 320319  Gujarat  Ahmedabad   Viramgam         Castor Seed  Castor seed   FAQ
# 320320  Gujarat  Ahmedabad   Viramgam  Cummin Seed(Jeera)        Other   FAQ
# 320321  Gujarat  Ahmedabad   Viramgam  Cummin Seed(Jeera)        Other   FAQ
# 320322  Gujarat  Ahmedabad   Viramgam  Cummin Seed(Jeera)        Other   FAQ
#
#        Arrival_Date  Min_Price  Max_Price  Modal_Price  Commodity_Code  \
# 0        2006-01-03      600.0     1300.0       1100.0              81
# 1        2006-01-05     1100.0     1400.0       1300.0              81
# 2        2006-01-16     1500.0     1800.0       1800.0              81
# 3        2006-01-19      700.0      900.0        800.0              81
# 4        2006-01-24      500.0     1400.0       1000.0              81
# ...             ...        ...        ...          ...             ...
# 320318   2024-10-18     6525.0     6620.0       6570.0             123
# 320319   2024-10-19     6425.0     6580.0       6500.0             123
# 320320   2024-11-07    21450.0    22200.0      21825.0              42
# 320321   2024-10-19    21850.0    22850.0      22350.0              42
# 320322   2024-10-23    20850.0    23200.0      22025.0              42
#
#         Arrival_Day  Arrival_Month  Arrival_Year
# 0                 3              1          2006
# 1                 5              1          2006
# 2                16              1          2006
# 3                19              1          2006
# 4                24              1          2006
# ...             ...            ...           ...
# 320318           18             10          2024
# 320319           19             10          2024
# 320320            7             11          2024
# 320321           19             10          2024
# 320322           23             10          2024
#
# [320288 rows x 14 columns]

# %%
df.dtypes
# Out:
# State                     object
# District                  object
# Market                    object
# Commodity                 object
# Variety                   object
# Grade                     object
# Arrival_Date      datetime64[ns]
# Min_Price                float64
# Max_Price                float64
# Modal_Price              float64
# Commodity_Code             int64
# Arrival_Day                int32
# Arrival_Month              int32
# Arrival_Year               int32
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

catcols = df.select_dtypes(include='object')

for i in catcols:
    df[i] = le.fit_transform(df[i])
    
df
# Out:
#         State  District  Market  Commodity  Variety  Grade Arrival_Date  \
# 0           0         0       0         15       49      0   2006-01-03
# 1           0         0       0         15       49      0   2006-01-05
# 2           0         0       0         15       49      0   2006-01-16
# 3           0         0       0         15       49      0   2006-01-19
# 4           0         0       0         15       49      0   2006-01-24
# ...       ...       ...     ...        ...      ...    ...          ...
# 320318      0         0      14         23       17      0   2024-10-18
# 320319      0         0      14         23       17      0   2024-10-19
# 320320      0         0      14         36       49      0   2024-11-07
# 320321      0         0      14         36       49      0   2024-10-19
# 320322      0         0      14         36       49      0   2024-10-23
#
#         Min_Price  Max_Price  Modal_Price  Commodity_Code  Arrival_Day  \
# 0           600.0     1300.0       1100.0              81            3
# 1          1100.0     1400.0       1300.0              81            5
# 2          1500.0     1800.0       1800.0              81           16
# 3           700.0      900.0        800.0              81           19
# 4           500.0     1400.0       1000.0              81           24
# ...           ...        ...          ...             ...          ...
# 320318     6525.0     6620.0       6570.0             123           18
# 320319     6425.0     6580.0       6500.0             123           19
# 320320    21450.0    22200.0      21825.0              42            7
# 320321    21850.0    22850.0      22350.0              42           19
# 320322    20850.0    23200.0      22025.0              42           23
#
#         Arrival_Month  Arrival_Year
# 0                   1          2006
# 1                   1          2006
# 2                   1          2006
# 3                   1          2006
# 4                   1          2006
# ...               ...           ...
# 320318             10          2024
# 320319             10          2024
# 320320             11          2024
# 320321             10          2024
# 320322             10          2024
#
# [320288 rows x 14 columns]

# %%
corr = df.corr()

corr['Modal_Price']
# Out:
# State                  NaN
# District               NaN
# Market            0.165548
# Commodity        -0.076141
# Variety           0.029529
# Grade             0.273295
# Arrival_Date      0.288364
# Min_Price         0.970414
# Max_Price         0.989851
# Modal_Price       1.000000
# Commodity_Code   -0.032064
# Arrival_Day      -0.002992
# Arrival_Month     0.013533
# Arrival_Year      0.287218
# Name: Modal_Price, dtype: float64

# %%
variance = df.drop(columns='Arrival_Date', axis = 1).var()
variance
# Out:
# State             0.000000e+00
# District          0.000000e+00
# Market            1.510645e+01
# Commodity         1.084083e+03
# Variety           4.988489e+01
# Grade             9.769507e-01
# Min_Price         4.977803e+06
# Max_Price         8.184484e+06
# Modal_Price       6.586802e+06
# Commodity_Code    1.183415e+04
# Arrival_Day       7.659720e+01
# Arrival_Month     1.228270e+01
# Arrival_Year      2.911693e+01
# dtype: float64

# %% [markdown]
# ##### Here, we drop the columns State and District as their variance is 0, i.e., they have the same value for all the columns.
# ##### We also drop the Arrival_Date column because we have divided it into 3 columns, Arrival_Day, Arrival_Month and Arrival_Year.

# %%
df_edited = df.drop(columns={'State', 'District', 'Arrival_Date'}, axis=1)

df_edited
# Out:
#         Market  Commodity  Variety  Grade  Min_Price  Max_Price  Modal_Price  \
# 0            0         15       49      0      600.0     1300.0       1100.0
# 1            0         15       49      0     1100.0     1400.0       1300.0
# 2            0         15       49      0     1500.0     1800.0       1800.0
# 3            0         15       49      0      700.0      900.0        800.0
# 4            0         15       49      0      500.0     1400.0       1000.0
# ...        ...        ...      ...    ...        ...        ...          ...
# 320318      14         23       17      0     6525.0     6620.0       6570.0
# 320319      14         23       17      0     6425.0     6580.0       6500.0
# 320320      14         36       49      0    21450.0    22200.0      21825.0
# 320321      14         36       49      0    21850.0    22850.0      22350.0
# 320322      14         36       49      0    20850.0    23200.0      22025.0
#
#         Commodity_Code  Arrival_Day  Arrival_Month  Arrival_Year
# 0                   81            3              1          2006
# 1                   81            5              1          2006
# 2                   81           16              1          2006
# 3                   81           19              1          2006
# 4                   81           24              1          2006
# ...                ...          ...            ...           ...
# 320318             123           18             10          2024
# 320319             123           19             10          2024
# 320320              42            7             11          2024
# 320321              42           19             10          2024
# 320322              42           23             10          2024
#
# [320288 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))
sns.boxplot(df_edited)
# Out:
# <Axes: >

# %%
def iqr_clipping(df, columns, multiplier=1.5):
    df_clipped = df.copy()
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - multiplier * IQR
        upper_bound = Q3 + multiplier * IQR
        df_clipped[col] = df[col].clip(lower=lower_bound, upper=upper_bound)
    return df_clipped

outlier_cols = ['Market', 'Variety', 'Grade', 'Min_Price', 'Max_Price', 'Modal_Price','Commodity_Code']

df_clipped = iqr_clipping(df_edited, outlier_cols, multiplier=1.5)

plt.figure(figsize=(20, 5))
sns.boxplot(df_clipped)
# Out:
# <Axes: >

# %%
df_clipped
# Out:
#         Market  Commodity  Variety  Grade  Min_Price  Max_Price  Modal_Price  \
# 0            0         15       49      0      600.0     1300.0       1100.0
# 1            0         15       49      0     1100.0     1400.0       1300.0
# 2            0         15       49      0     1500.0     1800.0       1800.0
# 3            0         15       49      0      700.0      900.0        800.0
# 4            0         15       49      0      500.0     1400.0       1000.0
# ...        ...        ...      ...    ...        ...        ...          ...
# 320318      10         23       49      0     4250.0     6620.0       5740.0
# 320319      10         23       49      0     4250.0     6580.0       5740.0
# 320320      10         36       49      0     4250.0     6887.5       5740.0
# 320321      10         36       49      0     4250.0     6887.5       5740.0
# 320322      10         36       49      0     4250.0     6887.5       5740.0
#
#         Commodity_Code  Arrival_Day  Arrival_Month  Arrival_Year
# 0                   81            3              1          2006
# 1                   81            5              1          2006
# 2                   81           16              1          2006
# 3                   81           19              1          2006
# 4                   81           24              1          2006
# ...                ...          ...            ...           ...
# 320318             123           18             10          2024
# 320319             123           19             10          2024
# 320320              42            7             11          2024
# 320321              42           19             10          2024
# 320322              42           23             10          2024
#
# [320288 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

num_columns = len(df_clipped.columns)
ncols = 3
nrows = int(np.ceil(20 / ncols))

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5 * ncols, 4 * nrows))
axes = axes.flatten()

for i, column in enumerate(df_clipped.drop(columns={'Variety', 'Grade'}, axis=1).columns):
    sns.histplot(data=df_clipped[column], ax=axes[i], stat='density',color='skyblue', edgecolor='black', alpha=0.7)
    sns.kdeplot(data=df_clipped[column], ax=axes[i], color='red', linewidth=2)
    axes[i].set_title(f'KDE and Histogram of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Density')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df_clipped.skew()
# Out:
# Market            1.220890
# Commodity         0.179125
# Variety           0.000000
# Grade             0.000000
# Min_Price         1.091409
# Max_Price         1.141578
# Modal_Price       1.095925
# Commodity_Code    0.955098
# Arrival_Day       0.015062
# Arrival_Month     0.033226
# Arrival_Year     -0.012548
# dtype: float64

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

df_numeric = df_clipped.select_dtypes(include=['number'])

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_numeric)

pca = PCA()
pca_result = pca.fit_transform(df_scaled)

pca_df = pd.DataFrame(pca_result, columns=[f'PC{i+1}' for i in range(pca_result.shape[1])])

explained_variance_df = pd.DataFrame({
    'Principal Component': [f'PC{i+1}' for i in range(len(pca.explained_variance_ratio_))],
    'Explained Variance Ratio': pca.explained_variance_ratio_
})

print("PCA Results (First 5 Components):")
print(pca_df.head())
print("\nExplained Variance Ratios:")
print(explained_variance_df)
# Out:
# PCA Results (First 5 Components):
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.482396 -0.423958 -1.556995 -1.669081 -0.590443 -1.299914 -0.142716
# 1 -1.164251 -0.441431 -1.538114 -1.523788 -0.413203 -1.398943 -0.147785
# 2 -0.701607 -0.425245 -1.514354 -0.785717  0.603606 -1.550465 -0.171792
# 3 -1.662691 -0.384377 -1.511299 -0.646777  0.924026 -1.278147 -0.102374
# 4 -1.537981 -0.355842 -1.521022 -0.312869  1.387254 -1.316200 -0.130210
#
#         PC8       PC9          PC10          PC11
# 0 -0.069256  0.032318 -2.405295e-17  5.057240e-16
# 1  0.193074  0.001981  2.323099e-16  1.426102e-16
# 2  0.266092  0.050439  8.528130e-17  3.787367e-16
# 3  0.149783 -0.017031  2.023689e-16 -2.085738e-16
# 4 -0.153346 -0.026355  6.780757e-17 -2.640555e-16
#
# Explained Variance Ratios:
#    Principal Component  Explained Variance Ratio
# 0                  PC1              3.445250e-01
# 1                  PC2              1.468588e-01
# 2                  PC3              1.180652e-01
# 3                  PC4              1.150548e-01
# 4                  PC5              1.092167e-01
# 5                  PC6              8.463199e-02
# 6                  PC7              7.187165e-02
# 7                  PC8              9.130420e-03
# 8                  PC9              6.455126e-04
# 9                 PC10              1.705242e-17
# 10                PC11              0.000000e+00

# %%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
threshold = 0.90
n_components = np.argmax(cumulative_variance >= threshold) + 1

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), cumulative_variance, marker='o', label='Cumulative Variance')
plt.axhline(y=threshold, color='r', linestyle='--', label=f'{threshold*100}% Threshold')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot')
plt.legend()
plt.grid()
plt.show()

# %%
optimal_pca = PCA(n_components=n_components)
df_pca_transformed = optimal_pca.fit_transform(df_scaled)

print(f"Transformed dataset shape: {df_pca_transformed.shape}")
# Out:
# Transformed dataset shape: (320288, 6)
# array([[-1.48239622, -0.42395803, -1.55699514, -1.66908144, -0.59044286,
#         -1.29991354],
#        [-1.1642507 , -0.44143092, -1.53811379, -1.52378809, -0.41320276,
#         -1.39894305],
#        [-0.70160667, -0.42524458, -1.5143543 , -0.78571671,  0.60360622,
#         -1.55046484],
#        ...,
#        [ 4.54505597, -1.62720601,  0.51183821,  0.1568522 , -1.23848238,
#          1.55314768],
#        [ 4.5386432 , -1.59632645,  0.50086414,  0.7086336 ,  0.04458139,
#          1.45614465],
#        [ 4.5375478 , -1.58446562,  0.50863626,  0.96736425,  0.4210075 ,
#          1.4500072 ]])

# %%
from sklearn.model_selection import train_test_split

Features = df_pca_transformed
Labels = df_clipped['Modal_Price']

Features_train, Features_test, Labels_train, Labels_test = train_test_split(Features, Labels, test_size=0.2, shuffle=True, random_state=42)

# %%
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score

xg = XGBRegressor()
xg.fit(Features_train, Labels_train)
pred = xg.predict(Features_test)
print(xg.score(Features_test,Labels_test))
# Out:
# 0.9951811013373463

# %%
from sklearn.model_selection import cross_val_score, KFold

acc = cross_val_score(xg, Features, Labels, cv=KFold(n_splits=10, shuffle=True, random_state=42))
print(acc)
# Out:
# [0.99506643 0.99537481 0.99541098 0.99514106 0.99537598 0.99513452
#  0.9951105  0.99547421 0.99523562 0.99505625]

# %%
plt.scatter(Labels_test, pred)
plt.xlabel('Actual Answer')
plt.ylabel('Prediction')
plt.plot([min(Labels_test),max(Labels_test)],[min(pred),max(pred)],color='red')
